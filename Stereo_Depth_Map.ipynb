# %%
import numpy as np
import cv2 as cv2
from matplotlib import pyplot as plt

# %%
img = cv2.imread('unnamed.jpg',0)
height, width = img.shape

imgL = img[:, :width // 2]
imgR = img[:, width // 2:]

fig, ax = plt.subplots(1,2, figsize=(8,8))
ax[0].imshow(imgL)
ax[0].set_title("Left Image")
ax[1].imshow(imgR)
ax[1].set_title("Right Image")
# Out:
# Text(0.5, 1.0, 'Right Image')

# %%
stereo = cv2.StereoBM_create(numDisparities=16, blockSize=25)
disparity = stereo.compute(imgL,imgR)

plt.imshow(disparity,'gray')
plt.title('Disparity Map')
# Out:
# Text(0.5, 1.0, 'Disparity Map')

# %%
f = 1
baseline = 0.2
Tx = 0.5

depth = f * (baseline - Tx) / disparity
plt.imshow(depth, cmap='jet')
plt.title("Depth Map")
# Out:
# <ipython-input-108-b71677fde7f1>:5: RuntimeWarning: divide by zero encountered in divide
#   depth = f * (baseline - Tx) / disparity
# Text(0.5, 1.0, 'Depth Map')
